# %%
# 2-ой тип задания. Логическое "И"
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
t = int(input())
if s > 5 and t > 5:
    print("YES")
else:
    print("NO")

# %%
# and - это операнд логического "и"
# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (6, 8); (3, 5); (–7, 2); (7, 7); (9, 8); (–1, 3); (–4, 5); (6, 9); (2, –1).
# Сколько было запусков, при которых программа напечатала «YES»?

# %%
# РЕШЕНИЕ
# Рассмотрим условие при котором программа пишет "YES"
if s > 5 and t > 5:
    print("YES")
# Из условия видно, что для того чтобы программа написала "YES" s должно быть больше 5 и
# t должно быть больше 5. То есть оба условия должны выполняться
# Подставим в условие все вводимые данные и проверим какие из них удовлетворяют условиям

# %%
# ПОДСТАНОВКА

# %%
# Программа для проверки
s = int()
t = int()
num = 1
input_matrix = [[6, 8], [3, 5], [-7, 2], [7, 7], [9, 8], [-1, 3], 
                [-4, 5], [6, 9], [2, -1]]
for i in range(len(input_matrix)):
    for j in range(1):
        s = input_matrix[i][j]
        t = input_matrix[i][j+1]
        if s > 5 and t > 5:
            print(f" {num}) {s, t} - YES")
        else: 
            print(f" {num}) {s, t} - NO")
        num+=1
# Out:
#  1) (6, 8) - YES
#  2) (3, 5) - NO
#  3) (-7, 2) - NO
#  4) (7, 7) - YES
#  5) (9, 8) - YES
#  6) (-1, 3) - NO
#  7) (-4, 5) - NO
#  8) (6, 9) - YES
#  9) (2, -1) - NO

# %%
# Решение данной задачи на языке Python
s = int()
t = int()
kol_vo = int(0)
input_matrix = [[6, 8], [3, 5], [-7, 2], [7, 7], [9, 8], [-1, 3], 
                [-4, 5], [6, 9], [2, -1]]
for i in range(len(input_matrix)):
    for j in range(1):
        s = input_matrix[i][j]
        t = input_matrix[i][j+1]
        if s > 5 and t > 5:
            kol_vo+=1
print(f"Количество запусков при которых программа написа 'YES' = {kol_vo}")
# Out:
# Количество запусков при которых программа написа 'YES' = 4

# %%
# 3-ий тип задания. Введение третьей переменной
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
t = int(input())
A = int(input())
if (s > 10) or (t > A):
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (1, 2); (11, 2); (1, 12); (11, 12); (−11, −12); (−11, 12); (−12, 11); (10, 10); (10, 5).
# Укажите количество целых значений параметра A, при которых для указанных 
# входных данных программа напечатает «NO» три раза.

# %%
# РЕШЕНИЕ

# %%
# Программа для проверки 
s = int()
t = int()
A = int(1)
kolvo_no = int()
kolvo_numbers = int()
input_matrix = [[1, 2], [1, 12], [-11, -12], [-11, 12], 
[-12, 11], [10, 10], [10, 5]]
while (A < 12):
    for i in range(len(input_matrix)):
        for j in range(1):
            s = input_matrix[i][j]
            t = input_matrix[i][j+1]
            if (t < A):
                kolvo_no+=1            
    if (kolvo_no == 3):
        kolvo_numbers+=1
    A+=1
    kolvo_no = 0  
print(kolvo_numbers)
# Out:
# 5

# %%
# 4-ый тип задания. // - Деление на цело
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
k = int(input())
if s // 2 == k:
    print("ДА")
else:
    print("НЕТ")

# // - это операнд деления нацело
# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (1, 1); (8, 4); (14, 10); (20, 1); (7, 3); (10, 5); (10, 2); (4, 1); (1, 0).
# Сколько было запусков, при которых программа напечатала «ДА»?

# %%
#РЕШЕНИЕ

# %%
# Программа для проверки
s = int()
k = int()
test_num = 1
main_kolvo = int()
input_matrix = [[1,1], [8,4], [14,10], [20,1], [7,3], [10,5], [10,2], [4,1], [1,0]]
for i in range(len(input_matrix)):
    for j in range(1):
        s = input_matrix[i][j]
        k = input_matrix[i][j+1]
        if s // 2 == k:
            print(f" {test_num}) {s, t} - ДА")
            main_kolvo += 1
        else:
            print((f" {test_num}) {s, t} - НЕТ"))
    test_num += 1
print("-----------------------------------------------")
print(f"Итоговое число вывод программой слова 'ДА' = {main_kolvo}")
print(f"Ответ: {main_kolvo}")
# Out:
#  1) (1, 5) - НЕТ
#  2) (8, 5) - ДА
#  3) (14, 5) - НЕТ
#  4) (20, 5) - НЕТ
#  5) (7, 5) - ДА
#  6) (10, 5) - ДА
#  7) (10, 5) - НЕТ
#  8) (4, 5) - НЕТ
#  9) (1, 5) - ДА
# -------------------
# Итоговое число вывод программой слова 'ДА' = 4
# Ответ: 4

# %%
# 5-ый тип задания. * - операнд умножения
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
k = int(input())
if  s >= 2 * k:
    print("ДА")
else:
    print("НЕТ")

# * - это операнд умножения
# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (1, 2); (8, 4); (6, −12); (−5, −5); (3, 11); (—10, 12); (—10, −2); (4, 1); (2, 5).
# Сколько было запусков, при которых программа напечатала «ДА»?

# %%
# Решение

# %%
# Программа для проверки

s = int()
k = int()
test_num = 1
main_kolvo = int()
input_matrix = [[1,2], [8,4], [6,-12], [-5,-5], [3,11], 
                [-10,12], [-10,-2], [4,1], [2,5]]
for i in range(len(input_matrix)):
    for j in range(1):
        s = input_matrix[i][j]
        k = input_matrix[i][j+1]
    if s >= 2 * k:
        print(f" {test_num}) {s, k} - ДА")
        main_kolvo += 1
    else:
        print(f" {test_num}) {s, k} - НЕТ")
    test_num += 1
print("-----------------------------------------------")
print(f"Итоговое число вывод программой слова 'ДА' = {main_kolvo}")
print(f"Ответ: {main_kolvo}")
# Out:
#  1) (1, 2) - НЕТ
#  2) (8, 4) - ДА
#  3) (6, -12) - ДА
#  4) (-5, -5) - ДА
#  5) (3, 11) - НЕТ
#  6) (-10, 12) - НЕТ
#  7) (-10, -2) - НЕТ
#  8) (4, 1) - ДА
#  9) (2, 5) - НЕТ
# -----------------------------------------------
# Итоговое число вывод программой слова 'ДА' = 4
# Ответ: 4

# %%
# 6-ой тип задания. if not - если не
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
t = int(input())
if not ((s < -4) and (t >= 3)):
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (−5, −2); (5, 3); (−14, 3); (−12, 5); (5, –7); (10, 3); (−4, 3); (3, 0); (−4, 9).
# Сколько было запусков, при которых программа напечатала «NO»?

# %%
# РЕШЕНИЕ

# %%
# Программа для проверки

s = int()
t = int()
test_num = 1
main_kolvo = int()
input_matrix = [[-5,-2], [5,3], [-14,3], [-12,5], [5,-7], 
                [10,3], [-4,3], [3,0], [-4,9]]
for i in range(len(input_matrix)):
    for j in range(1):
        s = input_matrix[i][j]
        t = input_matrix[i][j+1]
        if not ((s < -4) and (t >= 3)):
            print(f" {test_num}) {s, t} - YES")
        else:
            print(f" {test_num}) {s, t} - NO")
            main_kolvo += 1
    test_num += 1
print("-----------------------------------------------")
print(f"Итоговое число вывод программой слова 'NO' = {main_kolvo}")
print(f"Ответ: {main_kolvo}")
# Out:
#  1) (-5, -2) - YES
#  2) (5, 3) - YES
#  3) (-14, 3) - NO
#  4) (-12, 5) - NO
#  5) (5, -7) - YES
#  6) (10, 3) - YES
#  7) (-4, 3) - YES
#  8) (3, 0) - YES
#  9) (-4, 9) - YES
# -----------------------------------------------
# Итоговое число вывод программой слова 'NO' = 2
# Ответ: 2

# %%
# 7-ой тип задания. % - деление с остатком
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
 k = int(input())
if s % 5 == k:
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (1, 2); (5, 0); (18, 3); (21; 1); (10, 2); (12, 1); (9; 4); (5, 5); (3, 3)
# Сколько было запусков, при которых программа напечатала «YES»?

# %%
# РЕШЕНИЕ 
# % - это операнд деления с остатком

# %%
# Программа для проверки
s = int()
k = int()
test_num = 1
main_kolvo = int()
input_matrix = [[1,2], [5,0], [18,3], [21,1], [10,2], 
                [12,1], [9,4], [5,5], [3,3]]
for i in range(len(input_matrix)):
    for j in range(1):
        s = input_matrix[i][j]
        k = input_matrix[i][j+1]
        if s % 5 == k:
            print(f" {test_num}) {s, t} - YES")
            main_kolvo += 1
        else:
            print(f" {test_num}) {s, t} - NO")            
    test_num += 1
print("-----------------------------------------------")
print(f"Итоговое число вывод программой слова 'YES' = {main_kolvo}")
print(f"Ответ: {main_kolvo}")
# Out:
#  1) (1, 3) - NO
#  2) (5, 3) - YES
#  3) (18, 3) - YES
#  4) (21, 3) - YES
#  5) (10, 3) - NO
#  6) (12, 3) - NO
#  7) (9, 3) - YES
#  8) (5, 3) - NO
#  9) (3, 3) - YES
# -----------------------------------------------
# Итоговое число вывод программой слова 'YES' = 5
# Ответ: 5

# %%
# ЗАДАНИЯ ДЛЯ ПОДГОТОВКИ

# %%
# 1-ый тип задания логическое "или"

# Задание 1
# Ниже приведена программа, записанная на языке программирования python:

s = int(input())
t = int(input())
if s > 7 or t > 7:
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t вводились следующие пары чисел:
# (1, 2); (8, 2); (1, 9); (10, 9); (–7, –8); (–7, 9); (–8, 10); (7, 7); (7, 5).

# Сколько было запусков, при которых программа напечатала «YES»?

# Задание 2
# Ниже приведена программа, записанная на языке программирования python:

s = int(input())
t = int(input())
if s < 5 or t < 5:
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t вводились следующие пары чисел:
# (5, 5); (5, 4); (-5, -5); (10, 9); (–7, 8); (5, 9); (–8, 7); (7, 7); (7, 5).

# Сколько было запусков, при которых программа напечатала «YES»?

s = int(input())
t = int(input())
if s < 5 or t > 5:
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t вводились следующие пары чисел:
# (5, 5); (5, 6); (-5, -5); (10, 9); (–7, 8); (5, 9); (–8, 7); (5, -7); (6, 4).

# Сколько было запусков, при которых программа напечатала «NO»?

# %%
# 2-ый тип задания логическое "и"

# Задание 1
# Ниже приведена программа, записанная на языке программирования python:

s = int(input())
t = int(input())
if s > 10 and t > 10:
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t вводились следующие пары чисел:
# (10, 10); (10, 6); (–4, 8); (2, 9); (12, 7); (–11, 4); (–8, 13); (10, 9); (11, 11).
# Сколько было запусков, при которых программа напечатала «NO»?

# Задание 2
# Ниже приведена программа, записанная на языке программирования python:

s = int(input())
t = int(input())
if s > 6 and t < 7:
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t вводились следующие пары чисел:
# (7, 3); (2, 7); (6, 10); (5, 3); (5, 4); (–11, 4); (–8, 9); (7, 3); (9, 1).
# Сколько было запусков, при которых программа напечатала «YES»?

# Задание 3
# Ниже приведена программа, записанная на языке программирования python:

s = int(input())
t = int(input())
if s < 1 and t < 2:
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t вводились следующие пары чисел:
# (3, 5); (4, 3); (4, −5); (0, 7); (0, −2); (−2, 1); (−2, 5); (−2, −4); (1, 2).
# Сколько было запусков, при которых программа напечатала «YES»?

# %%
# 3-ий тип задания. Введение третьей переменной

# Задание 1
# Ниже приведена программа, записанная на языке программирования python:

s = int(input())
 t = int(input())
 A = int(input())
if (s > A) or (t > 8):
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t вводились следующие пары чисел:
# (13, 2); (11, 12); (–12, 12); (2, –2); (–10, –10); (6, –5); (2, 8); (9, 10); (1, 13).
# Укажите наименьшее целое значение параметра A, при котором для указанных входных данных программа напечатает «NO» 3 раза.

# 3-ий тип задания. Введение третьей переменной

# Задание 2
# Ниже приведена программа, записанная на языке программирования python:

s = int(input())
 t = int(input())
 A = int(input())
if (s > A) or (t > 10):
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t вводились следующие пары чисел:
# (13, 2); (11, 12); (–12, 12); (2, –2); (–10, –10); (6, –5); (2, 8); (9, 10); (1, 13).
# Укажите наименьшее целое значение параметра A, при котором для указанных входных данных программа напечатает «NO» 5 раз.

# Задание 3
# Ниже приведена программа, записанная на языке программирования python:

s = int(input())
 t = int(input())
 A = int(input())
if (s > A) or (t > 11):
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t вводились следующие пары чисел:
# (13, 2); (11, 12); (–12, 12); (2, –2); (–10, –10); (6, –5); (2, 8); (9, 10); (1, 13).
# Укажите наименьшее целое значение параметра A, при котором для указанных входных данных программа напечатает «NO» 8 раз.

# %%
# 4-ый тип задания. // - Деление на цело

# Задание 1
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
k = int(input())
if s // 5 == k:
    print("ДА")
else:
    print("НЕТ")

# // - это операнд деления нацело
# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (5, 1); (19, 4); (50, 10); (20, 10); (18, 3); (10, 2); (10, 5); (4, 1); (3, 0).
# Сколько было запусков, при которых программа напечатала «ДА»?

# Задание 2
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
k = int(input())
if s // 7 == k:
    print("ДА")
else:
    print("НЕТ")

# // - это операнд деления нацело
# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (7, 1); (19, 3); (35, 5); (20, 2); (18, 3); (10, 1); (15, 1); (7, 1); (6, 0).
# Сколько было запусков, при которых программа напечатала «ДА»?

# Задание 3
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
k = int(input())
if s // 4 == k:
    print("ДА")
else:
    print("НЕТ")

# // - это операнд деления нацело
# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (6, 2); (19, 4); (20, 5); (21, 1); (15, 3); (10, 2); (15, 1); (4, 1); (2, 0).
# Сколько было запусков, при которых программа напечатала «НЕТ»?

# %%
# 5-ый тип задания. * - операнд умножения

# Задание 1
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
k = int(input())
if  s >= 5 * k:
    print("ДА")
else:
    print("НЕТ")

# * - это операнд умножения
# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (1, 2); (8, 1); (6, −12); (−6, −4); (3, 11); (—10, 12); (—1, −2); (5, 1); (25, 5).
# Сколько было запусков, при которых программа напечатала «ДА»?

# Задание 2
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
k = int(input())
if  s <= 3 * k:
    print("ДА")
else:
    print("НЕТ")

# * - это операнд умножения
# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (1, 3); (5, 1); (6, −12); (−6, −4); (3, 11); (—10, 12); (—1, −2); (3, 1); (15, 5).
# Сколько было запусков, при которых программа напечатала «ДА»?

# Задание 2
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
k = int(input())
if  s > 5 * k:
    print("ДА")
else:
    print("НЕТ")

# * - это операнд умножения
# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (1, 2); (8, 1); (6, −12); (−6, −4); (3, 11); (—10, 12); (—1, −2); (5, 1); (25, 5)..
# Сколько было запусков, при которых программа напечатала «НЕТ»?

# %%
# 6-ой тип задания. if not - если не

# Задание 1
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
t = int(input())
if not ((s < -4) and (t >= 3)):
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (−5, −2); (5, 3); (−14, 3); (−12, 5); (5, –7); (10, 3); (−4, 3); (3, 0); (−4, 9).
# Сколько было запусков, при которых программа напечатала «NO»?

# Задание 2
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
t = int(input())
if not ((s >= -4) and (t < 3)):
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (−5, −2); (5, 3); (−14, 3); (−12, 5); (5, –7); (10, 3); (−4, 3); (3, 0); (−4, 9).
# Сколько было запусков, при которых программа напечатала «NO»?

# Задание 3
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
t = int(input())
if not ((s > -4) or (t <= 3)):
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (−5, −2); (5, 3); (−14, 3); (−12, 5); (5, –7); (10, 3); (−4, 3); (3, 0); (−4, 9).
# Сколько было запусков, при которых программа напечатала «YES»?

# %%
# 7-ой тип задания. % - деление с остатком

# Задание 1
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
k = int(input())
if s % 5 == k:
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (1, 2); (5, 0); (18, 3); (21; 1); (10, 2); (12, 1); (9; 4); (5, 5); (3, 3)
# Сколько было запусков, при которых программа напечатала «YES»?

# Задание 2
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
k = int(input())
if s % 2 == k:
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (1, 1); (2, 0); (18, 3); (21; 1); (10, 2); (12, 1); (9; 1); (5, 5); (2, 0)
# Сколько было запусков, при которых программа напечатала «YES»?

# Задание 3
# Ниже приведена программа, записанная на языке программирования python

s = int(input())
k = int(input())
if s % 2 != k:  #( "!=" - не равно - знак неравенства)
    print("YES")
else:
    print("NO")

# Было проведено 9 запусков программы, при которых в качестве значений переменных s и t:
# (1, 1); (2, 0); (18, 3); (21; 1); (10, 2); (12, 1); (9; 1); (5, 5); (2, 0)
# Сколько было запусков, при которых программа напечатала «YES»?
